# %% [markdown]
# ## My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Dr.Binoy Nirmal**
#
# Medical Doctor

# %% [markdown]
# *I am interested in data science because I wish to specialize in Genomic Data Science.*

# %% [markdown]
# ### cell5 will Print a string "Hello World"

# %%
print ('Hello World')
# Out:
# Hello World

# %% [markdown]
# >Hello guys.
# >
# >>Hope you guys are doing alright.
#
# Here are my vitals
# 1. Temperature- 98.2°F
# 2. SpO2: 99%
# 3. Heart Rate: 102bpm
